# %%
# !pip install tensorflow-gpu==2.0.0

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.0.0'

# %%
import pandas as pd
import random
import re
from nltk.tokenize import word_tokenize, sent_tokenize
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # review_rating data EDA

# %%
review_rating = pd.read_csv('/content/drive/My Drive/review_rating.csv')

# %%
review_rating = review_rating.astype({'rating': 'category'})
review_rating.head()
# Out:
#                                               review rating
# 0  Great with a salad. Cooked on top of stove for...      4
# 1  This worked very well and is EASY.  I used not...      4
# 2  very very sweet. after i waited the 2 days i b...      4
# 3  This recipe was OVERLY too sweet.  I would sta...      2
# 4                                         Very good!      4

# %%
review_rating['rating'].value_counts().plot(kind='bar')

# %%
print(review_rating.groupby('rating').size().reset_index(name='count'))
# Out:
#   rating   count
# 0      1   12815
# 1      2   14122
# 2      3   40852
# 3      4  187333
# 4      5  187333

# %%
review_rating.isnull().values.any()
# Out:
# False

# %%
review_rating.drop_duplicates(inplace=True)
review_rating.duplicated().sum()
# Out:
# 0

# %%
print(review_rating.groupby('rating').size().reset_index(name='count'))
# Out:
#   rating   count
# 0      1   12784
# 1      2   14113
# 2      3   40786
# 3      4  186723
# 4      5  186512

# %%
len(review_rating)
# Out:
# 440918

# %%
review_rating['review'] = review_rating['review'].str.replace("[^a-zA-Z ]", '')
review_rating.head()
# Out:
#                                               review rating
# 0  Great with a salad Cooked on top of stove for ...      4
# 1  This worked very well and is EASY  I used not ...      4
# 2  very very sweet after i waited the  days i bou...      4
# 3  This recipe was OVERLY too sweet  I would star...      2
# 4                                          Very good      4

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords  
stopwords.words('english')[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

sentences = []
stop_words = set(stopwords.words('english')) 

for i in review_rating['review']:
    sentence = word_tokenize(i)
    result = []
    
    for word in sentence:
        word = word.lower() # 모든 단어를 소문자화하여 단어의 개수를 줄입니다.
        if word not in stop_words:
            if len(word) > 2:
                result.append(word)
    sentences.append(result)

# %%
print(sentences[:5])
# Out:
# [['great', 'salad', 'cooked', 'top', 'stove', 'minutesadded', 'shake', 'cayenne', 'pinch', 'salt', 'used', 'low', 'fat', 'sour', 'cream', 'thanks'], ['worked', 'well', 'easy', 'used', 'quite', 'whole', 'package', 'white', 'chips', 'great'], ['sweet', 'waited', 'days', 'bought', 'pints', 'raspberries', 'added', 'mix', 'going', 'add', 'cake', 'filling', 'today', 'take', 'photo'], ['recipe', 'overly', 'sweet', 'would', 'start', 'cup', 'sugar', 'jsut', 'add', 'cups', 'way', 'much', 'back', 'grocery', 'store', 'buy', 'raspberries', 'made', 'much', 'mix', 'overall', 'would', 'long', 'narrow', 'box', 'raspberries', 'perfect', 'fit', 'recipe', 'plus', 'little', 'extra', 'impressed', 'recipe', 'exceptionally', 'oversweet', 'make', 'simple', 'recipe', 'make', 'sure', 'add', 'less', 'sugar'], ['good']]

# %%
max_words = 35000
tokenizer = Tokenizer(num_words=max_words) # 상위 35,000개의 단어만 보존
tokenizer.fit_on_texts(sentences)
review_data = tokenizer.texts_to_sequences(sentences)

# %%
print(review_data[:5])
# Out:
# [[7, 97, 65, 85, 721, 1699, 446, 790, 71, 3, 216, 187, 209, 43, 6], [188, 33, 12, 3, 112, 96, 907, 169, 240, 7], [50, 2241, 577, 515, 3210, 1401, 10, 109, 173, 23, 75, 179, 359, 277, 629], [1, 1043, 50, 13, 658, 55, 36, 10209, 23, 210, 47, 22, 171, 1164, 432, 622, 1401, 2, 22, 109, 402, 13, 250, 8125, 745, 1401, 77, 832, 1, 537, 15, 104, 915, 1, 3917, 12010, 5, 107, 1, 5, 78, 23, 140, 36], [4]]

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in review_data))
print('리뷰의 평균 길이 :',sum(map(len, review_data))/len(review_data))
plt.hist([len(s) for s in review_data], bins=200)
plt.xlabel('length of Data')
plt.ylabel('number of Data')
plt.show()
# Out:
# 리뷰의 최대 길이 : 619
# 리뷰의 평균 길이 : 26.45106573104296

# %%
max_len = 60 # 전체 데이터의 길이는 60으로 맞춘다.
review_data = pad_sequences(review_data, maxlen=max_len)

# %%
rating_data = np.array(review_rating['rating'])

# %% [markdown]
# # Fasttext

# %%
from __future__ import print_function
from gensim.models import KeyedVectors

# Creating the model
eng_model = KeyedVectors.load_word2vec_format('/content/drive/My Drive/wiki.en.vec')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# Getting the tokens 
words = []
for word in eng_model.vocab:
    words.append(word)

# %%
# Printing out number of tokens available
print("Number of Tokens: {}".format(len(words)))
# Out:
# Number of Tokens: 2519370

# %%
# Printing out the dimension of a word vector 
print("Dimension of a word vector: {}".format(
    len(eng_model[words[0]])
))
# Out:
# Dimension of a word vector: 300

# %%
# Print out the vector of a word 
print("Vector components of a word: {}".format(
    eng_model[words[0]]
))
# Out:
# Vector components of a word: [-2.3167e-02 -4.2483e-03 -1.0572e-01  4.2783e-02 -1.4316e-01 -7.8954e-02
#   7.8187e-02 -1.9454e-01  2.2303e-02  3.1207e-01  5.7462e-02 -1.1589e-01
#   9.6633e-02 -9.3229e-02 -3.4229e-02 -1.4652e-01 -1.1094e-01 -1.1102e-01
#   6.7728e-02  1.0023e-01 -6.7413e-02  2.3761e-01 -1.3105e-01 -8.3979e-03
#  -1.0593e-01  2.4526e-01  6.5903e-02 -2.3740e-01 -1.0758e-01  5.7082e-03
#  -8.1413e-02  2.6264e-01 -5.2461e-02  2.0306e-01  5.0620e-02 -1.8866e-01
#  -1.1494e-01 -2.5752e-01  4.6799e-02 -5.0525e-02  6.2650e-02  1.5433e-01
#  -5.6289e-02 -4.8437e-02 -9.9688e-02 -3.5332e-02 -9.1647e-02 -8.1151e-02
#  -1.0844e-03 -8.4140e-02 -1.3026e-01  1.4980e-02 -8.6276e-02 -5.3041e-02
#  -1.0644e-01 -4.2314e-02  8.6469e-02  2.2614e-01 -1.6078e-01  1.8845e-01
#   5.3098e-02 -2.1475e-01  1.6699e-01 -1.4442e-01 -1.5930e-01  6.2456e-03
#  -7.6630e-02 -9.1568e-02 -2.8984e-01  2.7078e-02  2.1275e-02  2.3939e-02
#   1.4903e-01 -3.3062e-01 -9.7811e-02 -3.3814e-02  7.0587e-02  2.3294e-02
#   6.5382e-02  1.8716e-01 -1.3444e-01  1.4431e-01 -2.6800e-02 -2.2903e-02
#   3.4232e-03  1.3892e-01  4.6106e-02 -5.4170e-02  8.4399e-03 -1.5362e-01
#  -1.4735e-01  6.5191e-02 -2.2883e-02 -1.4498e-01 -1.6917e-01 -1.9215e-01
#   1.0611e-01  1.6780e-03 -1.6331e-01 -7.3070e-02  1.1576e-01  8.3567e-02
#  -6.0317e-02 -6.4714e-02  1.5305e-01 -1.1949e-01  1.6684e-01  1.4109e-01
#   4.6036e-02 -6.0393e-02  4.6595e-02 -1.1558e-01  4.4184e-02 -2.3124e-02
#   2.5860e-02 -1.1653e-01  1.0936e-02  8.9398e-02 -1.5900e-02  1.4866e-01]

# %%
print(words[0])
# Out:
# ,

# %%
words[50]
# Out:
# 'you'

# %%
embedding_dict = dict()
for word in words:
    embedding_dict[word] = eng_model[word]

# %%
vocab_size = len(tokenizer.word_index.items()) + 1
embedding_matrix = np.zeros((vocab_size, 300))
# 단어 집합 크기의 행과 100개의 열을 가지는 행렬 생성. 값은 전부 0으로 채워진다.
np.shape(embedding_matrix)
# Out:
# (164480, 300)

# %%
for word, i in tokenizer.word_index.items(): # 훈련 데이터의 단어 집합에서 단어를 1개씩 꺼내온다.
    temp = embedding_dict.get(word) # 단어(key) 해당되는 임베딩 벡터의 300개의 값(value)를 임시 변수에 저장
    if temp is not None:
        embedding_matrix[i] = temp # 임수 변수의 값을 단어와 맵핑되는 인덱스의 행에 삽입

# %%
embedding_matrix.shape
# Out:
# (164480, 300)

# %%
rating_data
# Out:
# array([4, 4, 4, ..., 5, 5, 5])

# %%
rating_data = to_categorical(rating_data)

# %%
x_train, x_test, y_train, y_test = train_test_split(review_data, rating_data, test_size=0.1, random_state=0, stratify=rating_data)

# %%
x_train.shape,x_test.shape, y_train.shape, y_test.shape
# Out:
# ((396826, 60), (44092, 60), (396826, 6), (44092, 6))

# %% [markdown]
# # 1. LSTM으로 리뷰 점수 분석

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
model = Sequential()
e = Embedding(vocab_size, 300, weights=[embedding_matrix], input_length=max_len, trainable=False)
model.add(e)
model.add(LSTM(128))
model.add(Dense(6, activation='softmax'))

adam = Adam(learning_rate=0.01)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', f1_m])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 60, 300)           49344000
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               219648
# _________________________________________________________________
# dense (Dense)                (None, 6)                 774
# =================================================================
# Total params: 49,564,422
# Trainable params: 220,422
# Non-trainable params: 49,344,000
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test))
# Out:
# Train on 396826 samples, validate on 44092 samples
# Epoch 1/20
# 396826/396826 [==============================] - 431s 1ms/sample - loss: 0.8020 - accuracy: 0.6469 - f1_m: 0.6297 - val_loss: 0.7797 - val_accuracy: 0.6583 - val_f1_m: 0.6467
# Epoch 2/20
# 396826/396826 [==============================] - 434s 1ms/sample - loss: 0.7690 - accuracy: 0.6619 - f1_m: 0.6497 - val_loss: 0.7731 - val_accuracy: 0.6618 - val_f1_m: 0.6494
# Epoch 3/20
# 396826/396826 [==============================] - 428s 1ms/sample - loss: 0.7619 - accuracy: 0.6650 - f1_m: 0.6529 - val_loss: 0.7753 - val_accuracy: 0.6582 - val_f1_m: 0.6429
# Epoch 4/20
# Epoch 19/20
# 396826/396826 [==============================] - 431s 1ms/sample - loss: 0.7299 - accuracy: 0.6784 - f1_m: 0.6685 - val_loss: 0.7719 - val_accuracy: 0.6624 - val_f1_m: 0.6504
# Epoch 20/20
# 396826/396826 [==============================] - 430s 1ms/sample - loss: 0.7287 - accuracy: 0.6794 - f1_m: 0.6698 - val_loss: 0.7717 - val_accuracy: 0.6623 - val_f1_m: 0.6533

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper right')

plt.show()

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

acc_ax.plot(history.history['accuracy'], 'b', label='train acc')
acc_ax.plot(history.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')

plt.show()

# %% [markdown]
# # 2. LSTM으로 리뷰 점수 분석

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
model = Sequential()
e = Embedding(vocab_size, 300, weights=[embedding_matrix], input_length=max_len, trainable=False)
model.add(e)
model.add(LSTM(64))
model.add(Dense(6, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', f1_m])

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_11 (Embedding)     (None, 60, 300)           49154700
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 64)                93440
# _________________________________________________________________
# dense_9 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 49,248,530
# Trainable params: 93,830
# Non-trainable params: 49,154,700
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=4, batch_size=64, validation_data=(x_val, y_val))
# Out:
# Train on 216068 samples, validate on 92601 samples
# Epoch 1/4
# 216068/216068 [==============================] - 544s 3ms/sample - loss: 0.8419 - accuracy: 0.6312 - f1_m: 0.6029 - val_loss: 0.8024 - val_accuracy: 0.6462 - val_f1_m: 0.6287
# Epoch 2/4
# 216068/216068 [==============================] - 507s 2ms/sample - loss: 0.7662 - accuracy: 0.6641 - f1_m: 0.6494 - val_loss: 0.7585 - val_accuracy: 0.6674 - val_f1_m: 0.6538
# Epoch 3/4
# 216068/216068 [==============================] - 498s 2ms/sample - loss: 0.7418 - accuracy: 0.6743 - f1_m: 0.6614 - val_loss: 0.7488 - val_accuracy: 0.6719 - val_f1_m: 0.6608
# Epoch 4/4
# 216068/216068 [==============================] - 492s 2ms/sample - loss: 0.7237 - accuracy: 0.6828 - f1_m: 0.6710 - val_loss: 0.7443 - val_accuracy: 0.6730 - val_f1_m: 0.6628

# %%
print("\n 테스트 정확도: %.4f" % (model.evaluate(x_test, y_test)[1]*100))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  테스트 정확도: 67.3742

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper right')

# acc_ax.plot(history.history['accuracy'], 'b', label='train acc')
# acc_ax.plot(history.history['val_accuracy'], 'g', label='val acc')
# acc_ax.set_ylabel('accuracy')
# acc_ax.legend(loc='upper left')

plt.show()

# %%
model.save('model/fasttext_model.h5')

# %%
model.save_weights('model/fasttext_model_weights.h5')

# %% [markdown]
# # Glove

# %%
import numpy as np
embedding_dict = dict()
f = open('data/glove.6B/glove.6B.300d.txt', encoding="utf8")

for line in f:
    word_vector = line.split()
    word = word_vector[0]
    word_vector_arr = np.asarray(word_vector[1:], dtype='float32') # 300개의 값을 가지는 array로 변환
    embedding_dict[word] = word_vector_arr
f.close()
print('%s개의 Embedding vector가 있습니다.' % len(embedding_dict))
# Out:
# 400000개의 Embedding vector가 있습니다.

# %%
vocab_size = 163848 + 1
embedding_matrix = np.zeros((vocab_size, 300))
# 단어 집합 크기의 행과 100개의 열을 가지는 행렬 생성. 값은 전부 0으로 채워진다.
np.shape(embedding_matrix)
# Out:
# (163849, 300)

# %%
tokenizer.word_index.items()
# Out:
# dict_items([
let', 219), ('pork', 220), ('ate', 221), ('wanted', 222), ('hit', 223), ('crust', 224), ('mushrooms', 225), ('tender', 226), ('frozen', 227), ('done', 228), ('yum', 229), ('corn', 230), ('want', 231), ('written', 232), ('pasta', 233), ('see', 234), ('tomato', 235), ('cookie', 236), ('end', 237), ('bacon', 238), ('spicy', 239), ('chips', 240), ('vanilla', 241), ('mixed', 242), ('favorite', 243), ('everything', 244), ('fantastic', 245), ('old', 246), ('super', 247), ('spices', 248), ('awesome', 249), ('times', 250), ('long', 251), ('ended', 252), ('lovely', 253), ('thick', 254), ...

# %%
for word, i in tokenizer.word_index.items(): # 훈련 데이터의 단어 집합에서 단어를 1개씩 꺼내온다.
    temp = embedding_dict.get(word) # 단어(key) 해당되는 임베딩 벡터의 300개의 값(value)를 임시 변수에 저장
    if temp is not None:
        embedding_matrix[i] = temp # 임수 변수의 값을 단어와 맵핑되는 인덱스의 행에 삽입

# %%
rating_data
# Out:
# array([4, 4, 4, ..., 5, 5, 5], dtype=int64)

# %%
rating_data = to_categorical(rating_data)

# %%
x_train, x_test, y_train, y_test = train_test_split(review_data, rating_data, test_size=0.3, random_state=0, stratify=rating_data)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.3, random_state=0, stratify=y_train)

# %%
x_train.shape, x_val.shape, x_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((216068, 60), (92601, 60), (132288, 60), (216068, 6), (92601, 6), (132288, 6))

# %% [markdown]
# # 1. LSTM으로 리뷰 점수 분석

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))
# Out:
# Using TensorFlow backend.

# %%
glove_model = Sequential()
e = Embedding(vocab_size, 300, weights=[embedding_matrix], input_length=max_len, trainable=False)
glove_model.add(e)
glove_model.add(LSTM(128))
glove_model.add(Dense(6, activation='softmax'))

glove_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', f1_m])

# %%
glove_model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_12 (Embedding)     (None, 60, 300)           49154700
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 128)               219648
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 774
# =================================================================
# Total params: 49,375,122
# Trainable params: 220,422
# Non-trainable params: 49,154,700
# _________________________________________________________________

# %%
history = glove_model.fit(x_train, y_train, epochs=5, batch_size=64, validation_data=(x_val, y_val))
# Out:
# Train on 216068 samples, validate on 92601 samples
# Epoch 1/5
# 216068/216068 [==============================] - 493s 2ms/sample - loss: 0.8230 - accuracy: 0.6399 - f1_m: 0.6179 - val_loss: 0.7681 - val_accuracy: 0.6623 - val_f1_m: 0.6500
# Epoch 2/5
# 216068/216068 [==============================] - 505s 2ms/sample - loss: 0.7482 - accuracy: 0.6713 - f1_m: 0.6590 - val_loss: 0.7467 - val_accuracy: 0.6727 - val_f1_m: 0.6599
# Epoch 3/5
# 216068/216068 [==============================] - 488s 2ms/sample - loss: 0.7153 - accuracy: 0.6865 - f1_m: 0.6753 - val_loss: 0.7438 - val_accuracy: 0.6726 - val_f1_m: 0.6642
# Epoch 4/5
# 216068/216068 [==============================] - 488s 2ms/sample - loss: 0.6862 - accuracy: 0.7000 - f1_m: 0.6902 - val_loss: 0.7445 - val_accuracy: 0.6741 - val_f1_m: 0.6671
# Epoch 5/5
# 216068/216068 [==============================] - 488s 2ms/sample - loss: 0.6561 - accuracy: 0.7134 - f1_m: 0.7057 - val_loss: 0.7581 - val_accuracy: 0.6687 - val_f1_m: 0.6635

# %%
print("\n 테스트 정확도: %.4f" % (glove_model.evaluate(x_test, y_test)[1]*100))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  테스트 정확도: 67.0363

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper right')

acc_ax.plot(history.history['accuracy'], 'b', label='train acc')
acc_ax.plot(history.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')

plt.show()
